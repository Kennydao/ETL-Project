# %%
# Dependencies and Setup
import pandas as pd
import csv
import os

# %%
# File to Load (Remember to Change These)
books_data_to_load = "Resources/book900k-1000k.csv"

# Read data file into into Pandas dataframe
books_df = pd.read_csv(books_data_to_load)

# %%
books_df.head()
# Out:
#        Id                                               Name          Authors  \
# 0  900000                                Cabinet 03: Weather  Jeffrey Kastner
# 1  900001  Workouts in a Binder for Swimmers, Triathletes...      Nick Hansen
# 2  900002                         Las 120 jornadas de Sodoma  Marquis de Sade
# 3  900004  The Traveler: An American Odyssey in the Himal...      Eric Hansen
# 4  900006                                     Vertical Smile   Richard Condon
#
#          ISBN  Rating  PublishYear  PublishMonth  PublishDay  \
# 0  1932698019    4.00         2004             2           1
# 1  1931382743    4.48         2005            18          11
# 2  8472233847    3.12         1992             1           3
# 3  0871563509    4.18         1995             6           6
# 4  0297994026    3.74         1972            20           4
#
#                          Publisher RatingDist5 RatingDist4 RatingDist3  \
# 0                          Cabinet         5:0         4:2         3:0
# 1                       Velo Press        5:24        4:17         3:3
# 2                         TusQuets      5:1745      4:2246      3:2935
# 3               Random House, Inc.         5:6         4:8         3:3
# 4  Littlehampton Book Services Ltd         5:7        4:17        3:13
#
#   RatingDist2 RatingDist1 RatingDistTotal  CountsOfReview Language  \
# 0         2:0         1:0         total:2               0      NaN
# 1         2:0         1:0        total:44               2      NaN
# 2      2:1753      1:1408     total:10087               9      NaN
# 3         2:0         1:0        total:17               1      NaN
# 4         2:2         1:0        total:39               1      NaN
#
#    pagesNumber                                        Description  \
# 0          112  Artwork by Joe Amrhein, Maria Blondeel, Spence...
# 1          101  This waterproof book of 100 swimming workouts ...
# 2          424  The 120 Days of Sodom by Marquis de Sade relat...
# 3          102  This loving memorial to Swift is a moving phot...
# 4          334                                                NaN
#
#    Count of text reviews
# 0                      0
# 1                      2
# 2                      9
# 3                      1
# 4                      1

# %%
books_df.shape
# Out:
# (40890, 20)

# %%
books_df.describe()
# Out:
#                   Id        Rating   PublishYear  PublishMonth    PublishDay  \
# count   40890.000000  40890.000000  40890.000000  40890.000000  40890.000000
# mean   949177.751431      3.469541   1998.890584      9.709636      6.346075
# std     29062.356909      1.242119      8.462135     10.235637      3.565110
# min    900000.000000      0.000000   1899.000000      1.000000      1.000000
# 25%    923881.250000      3.470000   1995.000000      1.000000      3.000000
# 50%    948838.500000      3.840000   2001.000000      4.000000      6.000000
# 75%    974600.250000      4.090000   2005.000000     17.000000      9.000000
# max    999998.000000      5.000000   2020.000000     31.000000     12.000000
#
#        CountsOfReview   pagesNumber  Count of text reviews
# count    40890.000000  40890.000000           40890.000000
# mean         8.834238    276.196747               8.834238
# std         71.253610    505.166816              71.253610
# min          0.000000      0.000000               0.000000
# 25%          0.000000    153.000000               0.000000
# 50%          1.000000    241.000000               1.000000
# 75%          4.000000    340.000000               4.000000
# max       6495.000000  80500.000000            6495.000000

# %%
columns = books_df.columns
columns
# Out:
# Index(['Id', 'Name', 'Authors', 'ISBN', 'Rating', 'PublishYear',
#        'PublishMonth', 'PublishDay', 'Publisher', 'RatingDist5', 'RatingDist4',
#        'RatingDist3', 'RatingDist2', 'RatingDist1', 'RatingDistTotal',
#        'CountsOfReview', 'Language', 'pagesNumber', 'Description',
#        'Count of text reviews'],
#       dtype='object')

# %%
# drop unused columns
books_df.drop(columns = ['RatingDist5', 'RatingDist4',
       'RatingDist3', 'RatingDist2', 'RatingDist1', 'RatingDistTotal','pagesNumber'], inplace=True)

# %%
books_df.head()
# Out:
#        Id                                               Name          Authors  \
# 0  900000                                Cabinet 03: Weather  Jeffrey Kastner
# 1  900001  Workouts in a Binder for Swimmers, Triathletes...      Nick Hansen
# 2  900002                         Las 120 jornadas de Sodoma  Marquis de Sade
# 3  900004  The Traveler: An American Odyssey in the Himal...      Eric Hansen
# 4  900006                                     Vertical Smile   Richard Condon
#
#          ISBN  Rating  PublishYear  PublishMonth  PublishDay  \
# 0  1932698019    4.00         2004             2           1
# 1  1931382743    4.48         2005            18          11
# 2  8472233847    3.12         1992             1           3
# 3  0871563509    4.18         1995             6           6
# 4  0297994026    3.74         1972            20           4
#
#                          Publisher  CountsOfReview Language  pagesNumber  \
# 0                          Cabinet               0      NaN          112
# 1                       Velo Press               2      NaN          101
# 2                         TusQuets               9      NaN          424
# 3               Random House, Inc.               1      NaN          102
# 4  Littlehampton Book Services Ltd               1      NaN          334
#
#                                          Description  Count of text reviews
# 0  Artwork by Joe Amrhein, Maria Blondeel, Spence...                      0
# 1  This waterproof book of 100 swimming workouts ...                      2
# 2  The 120 Days of Sodom by Marquis de Sade relat...                      9
# 3  This loving memorial to Swift is a moving phot...                      1
# 4                                                NaN                      1

# %%
language_counts = books_df.groupby('Language').count()
language_counts.shape
# Out:
# (30, 13)

# %%
# replace all NaN value in Language column by eng

values ={'Language':'eng'}
books_df.fillna(value = values, inplace=True)

# %%
books_df
# Out:
#            Id                                               Name  \
# 0      900000                                Cabinet 03: Weather
# 1      900001  Workouts in a Binder for Swimmers, Triathletes...
# 2      900002                         Las 120 jornadas de Sodoma
# 3      900004  The Traveler: An American Odyssey in the Himal...
# 4      900006                                     Vertical Smile
# ...       ...                                                ...
# 40885  999991  Gendered Talk at Work: Constructing Gender Ide...
# 40886  999992  Good Will Toward Men: Women Talk Candidly abou...
# 40887  999993  Would You Rather . . . ?: The Outrageous Book ...
# 40888  999997  Addictions Treatment for Older Adults: Evaluat...
# 40889  999998                                     Within/Without
#
#                  Authors        ISBN  Rating  PublishYear  PublishMonth  \
# 0        Jeffrey Kastner  1932698019    4.00         2004             2
# 1            Nick Hansen  1931382743    4.48         2005            18
# 2        Marquis de Sade  8472233847    3.12         1992             1
# 3            Eric Hansen  0871563509    4.18         1995             6
# 4         Richard Condon  0297994026    3.74         1972            20
# ...                  ...         ...     ...          ...           ...
# 40885      Janet  Holmes  1405117591    4.28         2006            21
# 40886        Jack Kammer  0312104715    0.00         1994             1
# 40887         Randy Horn  0761124209    3.81         2001             1
# 40888     Kathryn Graham  1560248572    0.00         1995             2
# 40889  Kathryn T.S. Bass  097495974X    5.00         2005             1
#
#        PublishDay                        Publisher  CountsOfReview Language  \
# 0               1                          Cabinet               0      eng
# 1              11                       Velo Press               2      eng
# 2               3                         TusQuets               9      eng
# 3               6               Random House, Inc.               1      eng
# 4               4  Littlehampton Book Services Ltd               1      eng
# ...           ...                              ...             ...      ...
# 40885           7                  Wiley-Blackwell               0      eng
# 40886           2               St. Martin's Press               0      eng
# 40887          10       Workman Publishing Company              14      eng
# 40888           2                        Routledge               0      eng
# 40889           3           Pilgrims Process, Inc.               0      eng
#
#        pagesNumber                                        Description  \
# 0              112  Artwork by Joe Amrhein, Maria Blondeel, Spence...
# 1              101  This waterproof book of 100 swimming workouts ...
# 2              424  The 120 Days of Sodom by Marquis de Sade relat...
# 3              102  This loving memorial to Swift is a moving phot...
# 4              334                                                NaN
# ...            ...                                                ...
# 40885          251  <i>Gendered Talk at Work</i> examines how wome...
# 40886          231  In interviews with gender issues journalist Ja...
# 40887          400  <i>Would You Rather...?</i> takes the idea of ...
# 40888          258  Here is a detailed description of an innovativ...
# 40889           36                                                NaN
#
#        Count of text reviews
# 0                          0
# 1                          2
# 2                          9
# 3                          1
# 4                          1
# ...                      ...
# 40885                      0
# 40886                      0
# 40887                     14
# 40888                      0
# 40889                      0
#
# [40890 rows x 14 columns]

# %%
rating_counts = books_df.groupby("Rating").count()
rating_counts.head()
#rating_counts.shape
# Out:
#           Id  Name  Authors  ISBN  PublishYear  PublishMonth  PublishDay  \
# Rating
# 0.00    4013  4013     4013  4008         4013          4013        4013
# 1.00      93    93       93    92           93            93          93
# 1.33       1     1        1     1            1             1           1
# 1.50      11    11       11    11           11            11          11
# 1.55       1     1        1     1            1             1           1
#
#         Publisher  CountsOfReview  Language  pagesNumber  Description  \
# Rating
# 0.00         3961            4013       127         4013         2913
# 1.00           93              93        10           93           69
# 1.33            1               1         0            1            0
# 1.50            9              11         0           11            9
# 1.55            1               1         0            1            1
#
#         Count of text reviews
# Rating
# 0.00                     4013
# 1.00                       93
# 1.33                        1
# 1.50                       11
# 1.55                        1

# %%
author_counts = author_list = books_df.Authors.nunique()
author_counts
# Out:
# 28666

# %%
author_list = books_df.groupby("Authors").nunique()['Authors']

# %%
author_list_df = pd.DataFrame(author_list)

# %%
author_list_df
# Out:
#                           Authors
# Authors
# 'Izz al-Din Ibn al-Athir        1
# 50 Cent                         1
# 6' Ferret Writers' Group        1
# A H Keesman-Marwitz             1
# A. Ashley                       1
# ...                           ...
# Øivind Storm Bjerke             1
# Ānandamūrti                     1
# Дарья Донцова                   1
# جبرا إبراهيم جبرا               1
# مسلم بن الحجاج                  1
#
# [28666 rows x 1 columns]
